# %%
import pandas as pd
import numpy as np
from kmapper import KeplerMapper
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt
from kmapper.cover import Cover
from sklearn.cluster import DBSCAN
# Out:
# /home/ace/.local/lib/python3.12/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
df = pd.read_csv("./SuperScience/vep_super_science_v2_ubiq321_ds.csv")
df_meta = pd.read_csv("SuperScience/Metadata-SuperScience.csv")
labels = []
for row in df.iterrows():
    r = df_meta.loc[df_meta['text_name'] == row[1]["text_name"]].head(1)
    try:
        names = r["Author"].iloc[0].split(",")[0]
    except:
        names = ""
    s = f"{r["Date"].iloc[0]}-{names}-{r["SuperScience Subgenre"].iloc[0]}-{r["Title"].iloc[0]}"
    labels.append(s)

print(labels)
df.insert(0, '', labels)
df.to_csv("./SuperScience/SuperScienceLabeled.csv", index=False)
# Out:
# ['1639-L. W. C.-Animals-The English farrier, or, Countrey-mans treasure Shewing approved remedies to cure all diseases, hurts, maimes, maladies, and griefes in horses: and how to know the severall diseases that breed in them; with a description of every veine; how, and when to let them blood, according to the nature of their diseases. With directions to know the severall ages of them. Faithfully set forth according to art and approved experiment, for the benefit of gentlemen, farmers, inholders, husbandmen, and generall for all.; Verie perfect discourse, and order how to know the age of a horse, and the diseases that breede in him, with the remedies to cure the same', '1537-Erasmus-nan-Declamatio in laudem nobilissimÃ_ artis medicinÃ_. = A declamacion in the prayse and co[m]me[n]dation of the most hygh and excellent science of phisyke, made by the ryght famous clerke doctour Erasmus of Rotherdam, and newly translated out of Latyn into Englyshe. Cum priuilegio regali; De laude medicinae. English', '1633-Etten-Earth Sciences-Mathematicall recreations. Or a collection of sundrie problemes, extracted out of the ancient and moderne philosophers, as secrets in nature, and experiments in arithmeticke, geometrie, cosmographie, horolographie, astronomie, navigation, musicke, opticks, architecture, staticke, machanicks, chimestrie, waterworkes, fireworks, &c. ... Most of which were written first in Greeke and Latine, lately compiled in French, by Henry Van Etten Gent. And now delivered in the English tongue, with the examinations, corrections, and augmentations; RÃ©crÃ©ation mathÃ©maticque. English', '1570-Euclid.; Dee-Geometry-The elements of geometrie of the most auncient philosopher Euclide of Megara. Faithfully (now first) translated into the Englishe toung, by H. Billingsley, citizen of London. Whereunto are annexed certaine scholies, annotations, and inuentions, of the best mathematiciens, both of time past, and in this our age. With a very fruitfull prÃ_face made by M. I. Dee, specifying the chiefe mathematicall scie[n]ces, what they are, and wherunto commodious: where, also, are disclosed certaine new secrets mathematicall and mechanicall, vntill these our daies, greatly missed; Elements. English', '1634-Evans-Substances-The vniversall medicine: or The vertues of the antimoniall cup Collected out of the experiments, and observations of the most famous, learned, and best approved philosophers, and physicians, that have written of that subject. By Iohn Evans minister, and preacher of Gods Word.', '1622-Everard-nan-Somewhat vvritten by occasion of three sunnes seene at Tregnie in Cornewall, the 22. of December last. With other memorable occurents in other places.', '1583-Ewich-Plague-The duetie of a faithfull and wise magistrate, in preseruing and deliuering of the eommon [sic] wealth from infection, in the time of the plague or pestilence two bookes. Written in Latine by Iohn Ewich, ordinary phisition of the woorthie common wealth of Breame, and newlie turned into English by Iohn Stockwood schoolemaister of Tunbridge. ...; De officio fidelis et prudentis magistratus tempore pestilentiae rempublican a contagio praeservandi liberandique. English', '1585-Bostocke-nan-The difference betwene the auncient phisicke, first taught by the godly forefathers, consisting in vnitie peace and concord: and the latter phisicke proceeding from idolaters, ethnickes, and heathen: as Gallen, and such other consisting in dualitie, discorde, and contrarietie And wherein the naturall philosophie of Aristotle doth differ from the trueth of Gods worde, and is iniurious to Christianitie and sounde doctrine. By R.B. Esquire.', '1604-N. F.-Earth Sciences-The fruiterers secrets Containing directions, for the due time, and manner, of gathering all kindes of fruite, aswell stone-fruite as other: and how they are afterwards to be ordered in packing, carrying and conueighing them by land or by water; then in separating or culling them into diuers sorts; and lastly ...

# %%
#read in big names, row labled by year-author-subgenre-title
df = pd.read_csv("./SuperScience/SuperScienceLabeled.csv", index_col=0)

#drop non-numeric columns
columns_to_drop = ['text_name','text_key', 'html_name', 'chunk_index', '!UNRECOGNIZED', '!UNTAGGED', '!BLACKLISTED', '<# Word Tokens>', '<# Punctuation Tokens>', '<# Tokens>']
df = df.drop(columns=columns_to_drop)

df.head(10)
# Out:
#                                                     AbstractConcepts  \
# 1639-L. W. C.-Animals-The English farrier, or, ...          2.337789
# 1537-Erasmus-nan-Declamatio in laudem nobilissi...          3.210962
# 1633-Etten-Earth Sciences-Mathematicall recreat...          4.774546
# 1570-Euclid.; Dee-Geometry-The elements of geom...          5.880564
# 1634-Evans-Substances-The vniversall medicine: ...          5.073393
# 1622-Everard-nan-Somewhat vvritten by occasion ...          2.950820
# 1583-Ewich-Plague-The duetie of a faithfull and...          3.380282
# 1585-Bostocke-nan-The difference betwene the au...          5.440545
# 1604-N. F.-Earth Sciences-The fruiterers secret...          2.784539
# 1606-Fage-Treatments-Speculum Ã_grotorum. The s...          5.431737
#
#                                                     Acknowledge     Anger  \
# 1639-L. W. C.-Animals-The English farrier, or, ...     0.006104  0.018312
# 1537-Erasmus-nan-Declamatio in laudem nobilissi...     0.061356  0.184068
# 1633-Etten-Earth Sciences-Mathematicall recreat...     0.001258  0.037743
# 1570-Euclid.; Dee-Geometry-The elements of geom...     0.001389  0.002779
# 1634-Evans-Substances-The vniversall medicine: ...     0.000000  0.213767
# 1622-Everard-nan-Somewhat vvritten by occasion ...     0.019286  0.096432
# 1583-Ewich-Plague-The duetie of a faithfull and...     0.018884  0.166811
# 1585-Bostocke-nan-The difference betwene the au...     0.019191  0.069566
# 1604-N. F.-Earth Sciences-The fruiterers secret...     0.048681  0.000000
# 1606-Fage-Treatments-Speculum Ã_grotorum. The s...     0.000000  0.125016
#
#                                                      Apology     Aside  \
# 1639-L. W. C.-Animals-The English farrier, or, ...  0.000000  0.482207
# 1537-Erasmus-nan-Declamatio in laudem nobilissi...  0.000000  0.756724
# 1633-Etten-Earth Sciences-Mathematicall recreat...  0.000000  0.788838
# 1570-Euclid.; Dee-Geometry-The elements of geom...  0.000463  0.460985
# 1634-Evans-Substances-The vniversall medicine: ...  0.000000  0.342027
# 1622-Everard-nan-Somewhat vvritten by occasion ...  0.000000  0.829315
# 1583-Ewich-Plague-The duetie of a faithfull and...  0.000000  0.835628
# 1585-Bostocke-nan-The difference betwene the au...  0.000000  0.913954
# 1604-N. F.-Earth Sciences-The fruiterers secret...  0.000000  0.350501
# 1606-Fage-Treatments-Speculum Ã_grotorum. The s...  0.000000  0.211234
#
#                                                     Attack_Citation  \
# 1639-L. W. C.-Animals-The English farrier, or, ...              0.0
# 1537-Erasmus-nan-Declamatio in laudem nobilissi...              0.0
# 1633-Etten-Earth Sciences-Mathematicall recreat...              0.0
# 1570-Euclid.; Dee-Geometry-The elements of geom...              0.0
# 1634-Evans-Substances-The vniversall medicine: ...              0.0
# 1622-Everard-nan-Somewhat vvritten by occasion ...              0.0
# 1583-Ewich-Plague-The duetie of a faithfull and...              0.0
# 1585-Bostocke-nan-The difference betwene the au...              0.0
# 1604-N. F.-Earth Sciences-The fruiterers secret...              0.0
# 1606-Fage-Treatments-Speculum Ã_grotorum. The s...              0.0
#
#                                                     Authoritative_Citation  \
# 1639-L. W. C.-Animals-The English farrier, or, ...                0.000000
# 1537-Erasmus-nan-Declamatio in laudem nobilissi...                0.010226
# 1633-Etten-Earth Sciences-Mathematicall recreat...                0.005032
# 1570-Euclid.; Dee-Geometry-The elements of geom...                0.001698
# 1634-Evans-Substances-The vniversall medicine: ...                0.000000
# 1622-Everard-nan-Somewhat vvritten by occasion ...                0.000000
# 1583-Ewich-Plague-The duetie of a faithfull and...                0.001574
# 1585-Bostocke-nan-The difference betwene the au...                0.009595
# 1604-N. F.-Earth Sciences-The fruiterers secret...                0.000000
# 1606-Fage-Treatments-Speculum Ã_grotorum. The s...                0.000000
#
#                                                      Autobio  \
# 1639-L. W. C.-Animals-The English farrier, or, ...  0.000000
# 1537-Erasmus-nan-Declamatio in laudem nobilissi...  0.030678
# 1633-Etten-Earth Sciences-Mathematicall recreat...  0.002516
# 1570-Euclid.; Dee-Geometry-The elements of geom...  0.007565
# 1634-Evans-Substances-The vniversall medicine: ...  0.000000
# 1622-Everard-nan-Somewhat vvritten by occasion ...  0.231437
# 1583-Ewich-Plague-The duetie of a faithfull and...  0.062948
# 1585-Bostocke-nan-The difference betwene the au...  0.009595
# 1604-N. F.-Earth Sciences-The fruiterers secret...  0.000000
# 1606-Fage-Treatments-Speculum Ã_grotorum. The s...  0.000000
#
#                                                     Biographical_Time  \
# 1639-L. W. C.-Animals-The English farrier, or, ...           0.030519
# 1537-Erasmus-nan-Declamatio in laudem nobilissi...           0.337458
# 1633-Etten-Earth Sciences-Mathematicall recreat...           0.088068
# 1570-Euclid.; Dee-Geometry-The elements of geom...           0.042918
# 1634-Evans-Substances-The vniversall medicine: ...           0.042753
# 1622-Everard-nan-Somewhat vvritten by occasion ...           0.173578
# 1583-Ewich-Plague-The duetie of a faithfull and...           0.199858
# 1585-Bostocke-nan-The difference betwene the au...           0.357426
# 1604-N. F.-Earth Sciences-The fruiterers secret...           0.223931
# 1606-Fage-Treatments-Speculum Ã_grotorum. The s...           0.025865
#
#                                                        Cause  ...  \
# 1639-L. W. C.-Animals-The English farrier, or, ...  0.335714  ...
# 1537-Erasmus-nan-Declamatio in laudem nobilissi...  0.214746  ...
# 1633-Etten-Earth Sciences-Mathematicall recreat...  0.236526  ...
# 1570-Euclid.; Dee-Geometry-The elements of geom...  0.076728  ...
# 1634-Evans-Substances-The vniversall medicine: ...  0.085507  ...
# 1622-Everard-nan-Somewhat vvritten by occasion ...  0.520733  ...
# 1583-Ewich-Plague-The duetie of a faithfull and...  0.346211  ...
# 1585-Bostocke-nan-The difference betwene the au...  0.582916  ...
# 1604-N. F.-Earth Sciences-The fruiterers secret...  0.467335  ...
# 1606-Fage-Treatments-Speculum Ã_grotorum. The s...  0.319007  ...
#
#                                                     SubjectivePercept  \
# 1639-L. W. C.-Animals-The English farrier, or, ...           0.647012
# 1537-Erasmus-nan-Declamatio in laudem nobilissi...           1.840679
# 1633-Etten-Earth Sciences-Mathematicall recreat...           0.952393
# 1570-Euclid.; Dee-Geometry-The elements of geom...           1.213905
# 1634-Evans-Substances-The vniversall medicine: ...           0.798062
# 1622-Everard-nan-Somewhat vvritten by occasion ...           1.928640
# 1583-Ewich-Plague-The duetie of a faithfull and...           1.775120
# 1585-Bostocke-nan-The difference betwene the au...           1.885480
# 1604-N. F.-Earth Sciences-The fruiterers secret...           1.012560
# 1606-Fage-Treatments-Speculum Ã_grotorum. The s...           0.581972
#
#                                                     SubjectiveTime  \
# 1639-L. W. C.-Animals-The English farrier, or, ...        0.067143
# 1537-Erasmus-nan-Declamatio in laudem nobilissi...        0.317006
# 1633-Etten-Earth Sciences-Mathematicall recreat...        0.188717
# 1570-Euclid.; Dee-Geometry-The elements of geom...        0.035199
# 1634-Evans-Substances-The vniversall medicine: ...        0.114009
# 1622-Everard-nan-Somewhat vvritten by occasion ...        0.347155
# 1583-Ewich-Plague-The duetie of a faithfull and...        0.286411
# 1585-Bostocke-nan-The difference betwene the au...        0.283062
# 1604-N. F.-Earth Sciences-The fruiterers secret...        0.467335
# 1606-Fage-Treatments-Speculum Ã_grotorum. The s...        0.051731
#
#                                                     Substitution   Support  \
# 1639-L. W. C.-Animals-The English farrier, or, ...      0.018312  0.042727
# 1537-Erasmus-nan-Declamatio in laudem nobilissi...      0.030678  0.081808
# 1633-Etten-Earth Sciences-Mathematicall recreat...      0.016355  0.007549
# 1570-Euclid.; Dee-Geometry-The elements of geom...      0.009109  0.008028
# 1634-Evans-Substances-The vniversall medicine: ...      0.000000  0.000000
# 1622-Everard-nan-Somewhat vvritten by occasion ...      0.000000  0.096432
# 1583-Ewich-Plague-The duetie of a faithfull and...      0.004721  0.020458
# 1585-Bostocke-nan-The difference betwene the au...      0.019191  0.045578
# 1604-N. F.-Earth Sciences-The fruiterers secret...      0.009736  0.038945
# 1606-Fage-Treatments-Speculum Ã_grotorum. The s...      0.000000  0.094840
#
#                                                     TimeDate  TimeDuration  \
# 1639-L. W. C.-Animals-The English farrier, or, ...  0.024416      1.037661
# 1537-Erasmus-nan-Declamatio in laudem nobilissi...  0.000000      0.490848
# 1633-Etten-Earth Sciences-Mathematicall recreat...  0.015097      0.929747
# 1570-Euclid.; Dee-Geometry-The elements of geom...  0.001235      0.164571
# 1634-Evans-Substances-The vniversall medicine: ...  0.000000      0.498789
# 1622-Everard-nan-Somewhat vvritten by occasion ...  0.192864      1.639344
# 1583-Ewich-Plague-The duetie of a faithfull and...  0.012590      1.325045
# 1585-Bostocke-nan-The difference betwene the au...  0.009595      0.810804
# 1604-N. F.-Earth Sciences-The fruiterers secret...  0.107098      1.655146
# 1606-Fage-Treatments-Speculum Ã_grotorum. The s...  0.077596      1.646765
#
#                                                     TimeShift  Transformation  \
# 1639-L. W. C.-Animals-The English farrier, or, ...   0.274675        0.482207
# 1537-Erasmus-nan-Declamatio in laudem nobilissi...   0.092034        0.429492
# 1633-Etten-Earth Sciences-Mathematicall recreat...   0.260430        0.669317
# 1570-Euclid.; Dee-Geometry-The elements of geom...   0.056041        0.246857
# 1634-Evans-Substances-The vniversall medicine: ...   0.057004        0.370529
# 1622-Everard-nan-Somewhat vvritten by occasion ...   0.482160        0.462874
# 1583-Ewich-Plague-The duetie of a faithfull and...   0.350932        0.511449
# 1585-Bostocke-nan-The difference betwene the au...   0.280663        0.729244
# 1604-N. F.-Earth Sciences-The fruiterers secret...   1.022296        1.119657
# 1606-Fage-Treatments-Speculum Ã_grotorum. The s...   0.224167        0.512997
#
#                                                     Uncertainty   Updates
# 1639-L. W. C.-Animals-The English farrier, or, ...     0.402857  0.134286
# 1537-Erasmus-nan-Declamatio in laudem nobilissi...     0.705594  0.378362
# 1633-Etten-Earth Sciences-Mathematicall recreat...     0.763676  0.213880
# 1570-Euclid.; Dee-Geometry-The elements of geom...     0.360173  0.098187
# 1634-Evans-Substances-The vniversall medicine: ...     0.399031  0.299273
# 1622-Everard-nan-Somewhat vvritten by occasion ...     0.752170  0.443587
# 1583-Ewich-Plague-The duetie of a faithfull and...     1.180266  0.387127
# 1585-Bostocke-nan-The difference betwene the au...     0.940341  0.278264
# 1604-N. F.-Earth Sciences-The fruiterers secret...     0.759420  0.194723
# 1606-Fage-Treatments-Speculum Ã_grotorum. The s...     0.301763  0.090529
#
# [10 rows x 115 columns]

# %%
#scale the data
X = df.select_dtypes(include="number")
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X) #take X and scale to [0,1] with std dev 1

# %%
#mapper takes np arrays, but we should preserve row names 

X_scaled = pd.DataFrame(
    X_scaled,
    index=df.index,
    columns=df.columns
)

#check it
X_scaled.head(3)
# Out:
#                                                     AbstractConcepts  \
# 1639-L. W. C.-Animals-The English farrier, or, ...         -1.417809
# 1537-Erasmus-nan-Declamatio in laudem nobilissi...         -0.921178
# 1633-Etten-Earth Sciences-Mathematicall recreat...         -0.031865
#
#                                                     Acknowledge     Anger  \
# 1639-L. W. C.-Animals-The English farrier, or, ...    -0.405119 -0.786970
# 1537-Erasmus-nan-Declamatio in laudem nobilissi...     1.948848  0.816416
# 1633-Etten-Earth Sciences-Mathematicall recreat...    -0.611569 -0.599003
#
#                                                      Apology     Aside  \
# 1639-L. W. C.-Animals-The English farrier, or, ... -0.226867 -0.459604
# 1537-Erasmus-nan-Declamatio in laudem nobilissi... -0.226867  0.381520
# 1633-Etten-Earth Sciences-Mathematicall recreat... -0.226867  0.479919
#
#                                                     Attack_Citation  \
# 1639-L. W. C.-Animals-The English farrier, or, ...        -0.276041
# 1537-Erasmus-nan-Declamatio in laudem nobilissi...        -0.276041
# 1633-Etten-Earth Sciences-Mathematicall recreat...        -0.276041
#
#                                                     Authoritative_Citation  \
# 1639-L. W. C.-Animals-The English farrier, or, ...               -0.516989
# 1537-Erasmus-nan-Declamatio in laudem nobilissi...                0.379086
# 1633-Etten-Earth Sciences-Mathematicall recreat...               -0.076009
#
#                                                      Autobio  \
# 1639-L. W. C.-Animals-The English farrier, or, ... -0.561274
# 1537-Erasmus-nan-Declamatio in laudem nobilissi... -0.361305
# 1633-Etten-Earth Sciences-Mathematicall recreat... -0.544872
#
#                                                     Biographical_Time  \
# 1639-L. W. C.-Animals-The English farrier, or, ...          -0.996727
# 1537-Erasmus-nan-Declamatio in laudem nobilissi...           1.051245
# 1633-Etten-Earth Sciences-Mathematicall recreat...          -0.612748
#
#                                                        Cause  ...  \
# 1639-L. W. C.-Animals-The English farrier, or, ...  0.405030  ...
# 1537-Erasmus-nan-Declamatio in laudem nobilissi... -0.290281  ...
# 1633-Etten-Earth Sciences-Mathematicall recreat... -0.165094  ...
#
#                                                     SubjectivePercept  \
# 1639-L. W. C.-Animals-The English farrier, or, ...          -1.362960
# 1537-Erasmus-nan-Declamatio in laudem nobilissi...           0.909047
# 1633-Etten-Earth Sciences-Mathematicall recreat...          -0.781703
#
#                                                     SubjectiveTime  \
# 1639-L. W. C.-Animals-The English farrier, or, ...       -1.452522
# 1537-Erasmus-nan-Declamatio in laudem nobilissi...        0.711099
# 1633-Etten-Earth Sciences-Mathematicall recreat...       -0.399781
#
#                                                     Substitution   Support  \
# 1639-L. W. C.-Animals-The English farrier, or, ...     -0.297055 -0.226160
# 1537-Erasmus-nan-Declamatio in laudem nobilissi...      0.070946  0.333432
# 1633-Etten-Earth Sciences-Mathematicall recreat...     -0.355267 -0.729876
#
#                                                     TimeDate  TimeDuration  \
# 1639-L. W. C.-Animals-The English farrier, or, ... -0.249243     -0.078933
# 1537-Erasmus-nan-Declamatio in laudem nobilissi... -0.380727     -0.733989
# 1633-Etten-Earth Sciences-Mathematicall recreat... -0.299424     -0.208209
#
#                                                     TimeShift  Transformation  \
# 1639-L. W. C.-Animals-The English farrier, or, ...  -0.307183       -0.362729
# 1537-Erasmus-nan-Declamatio in laudem nobilissi...  -1.339923       -0.529961
# 1633-Etten-Earth Sciences-Mathematicall recreat...  -0.387732        0.230852
#
#                                                     Uncertainty   Updates
# 1639-L. W. C.-Animals-The English farrier, or, ...    -0.885202 -1.167718
# 1537-Erasmus-nan-Declamatio in laudem nobilissi...     0.132907  0.329480
# 1633-Etten-Earth Sciences-Mathematicall recreat...     0.328238 -0.679478
#
# [3 rows x 115 columns]

# %%
#pca two componenets 
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

print("Variance explained by each principle comp:", pca.explained_variance_ratio_)
print("Cumulative variance:", pca.explained_variance_ratio_.cumsum())
# Out:
# Variance explained by each principle comp: [0.14819593 0.05655883]
# Cumulative variance: [0.14819593 0.20475476]

# %%
#dimensionality reduction, project to PCA space with two most significant comps
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# X_pca will be used as the lens/ruler 
lens = X_pca

# %%
#Init. Kepler Mapper
mapper = KeplerMapper(verbose=1)
# Out:
# KeplerMapper(verbose=1)

# %%
#create cover 
cover = Cover(n_cubes=15, perc_overlap=0.1)

# %%
# Create Mapper graph
graph = mapper.map(
    lens,
    X_scaled,
    clusterer=DBSCAN(eps=10, min_samples=3),
    cover=cover
)
# Out:
# Mapping on data shaped (1979, 115) using lens shaped (1979, 2)
#
# Creating 225 hypercubes.
#
# Created 171 edges and 112 nodes in 0:00:00.320301.

# %%
tooltips = df.index.astype(str).to_numpy()

mapper.visualize(graph, path_html="./SuperScienceNetwork.html",
                 title="Super Science Network", custom_tooltips=tooltips)
# Out:
# Wrote visualization to: ./SuperScienceNetwork.html
# '<!DOCTYPE html>\n<html>\n\n<head>\n  <meta charset="utf-8">\n  <meta name="generator" content="KeplerMapper">\n  <title>Super Science Network | KeplerMapper</title>\n\n  <link rel="icon" type="image/png" href="http://i.imgur.com/axOG6GJ.jpg" />\n\n  <link href=\'https://fonts.googleapis.com/css?family=Roboto+Mono:700,300\' rel=\'stylesheet\' type=\'text/css\'>\n  <style>* {\n  margin: 0;\n  padding: 0;\n}\n\nhtml, body {\n  height: 100%;\n}\n\nbody {\n  font-family: "Roboto Mono", "Helvetica", sans-serif;\n  font-size: 14px;\n}\n\n#logo {\n  width:  85px;\n  height: 85px;\n}\n\n#display {\n  color: #95A5A6;\n  background: #212121;\n}\n\n#header {\n  background: #111111;\n}\n\n#print {\n  color: #000;\n  background: #FFF;\n}\n\nh1 {\n  font-size: 21px;\n  font-weight: 300;\n  font-weight: 300;\n}\n\nh2 {\n  font-size: 18px;\n  padding-bottom: 20px;\n  font-weight: 300;\n}\n\nh3 {\n  font-size: 14px;\n  font-weight: 700;\n  text-transform: uppercase;\n}\n\nh4 {\n  font-size: 13px;\n  font-weight: 700;\n  text-transform: uppercase;\n  padding-bottom:0px;\n}\n\n\n#meta_content h3 {\n  float: left;\n  padding-right: 8px;\n}\n\np, #tooltip_content h3, ol, ul, table {\n  padding-bottom: 10px;\n}\n\nol, ul {\n  padding-left: 20px;\n}\n\nol b {\n  display: block;\n}\n\na {\n  color: #16a085;\n  text-decoration: none;\n}\n\n.pane {\n  position: relative;\n}\n\n.pane-left {\n  float: left;\n}\n\n.pane-right {\n  float: right;\n}\n\na:hover {\n  color: #2ecc71;\n}\n\n.banner {\n  /* height: 35px; */\n  padding: 10px 0px;\n}\n\n\n#print #header {\n  background: #FFF;\n}\n\n\n#canvas {\n  width: 100%;\n}\n\n#svg {\n  position: absolute;\n}\n\n#toolbar {\n  padding-top: 5px;\n  margin-bottom: 5px;\n  width: 100%;\n}\n\n#display #toolbar {\n}\n\n#display .banner {\n  border-top: 1px solid #000;\n}\n\n.inline-block {\n  display: inline-block;\n}\n\n.tool_item {\n  padding-left: 10px;\n  padding-right: 10px;\n}\n\n.pane_content {\n  width: 300px;\n  height:100%;\n  padding: 20px;\n  overflow: auto;\n  display: none;\n}\n\n.pane {\n  z-index: 1;\n}\n\n#display .pane_content {\n  background: #191919;\n}\n\n#print .pane_content{\n  background: #FFF;\n}\n\n#meta_content::-webkit-scrollbar, #tooltip_content::-webkit-scrollbar {\n  width: 1em;\n}\n\n#meta_content::-webkit-scrollbar-track, #tooltip_content::-webkit-scrollbar-track {\n  -webkit-box-shadow: inset 0 0 6px rgba(0, 0, 0, 0.3);\n}\n\n#meta_content::-webkit-scrollbar-thumb, #tooltip_content::-webkit-scrollbar-thumb {\n  background-color: darkgrey;\n  outline: 1px solid slategrey;\n}\n\n.histogram {\n  display: block;\n  height: 100px;\n  padding-top: 50px;\n  clear: both;\n}\n\n#display .histogram {\n  opacity: 0.68;\n}\n\n.bin {\n  width: 10%;\n  float: left;\n}\n\n.bin div {\n  font-size: 10px;\n  display: block;\n  width: 35px;\n  margin-top: -30px;\n  text-align: right;\n  margin-left: -3px;\n  -webkit-transform: rotate(-90deg);\n  -moz-transform: rotate(-90deg);\n  -ms-transform: rotate(-90deg);\n  -o-transform: rotate(-90deg);\n}\n\n.histogram:hover {\n  opacity: 1.;\n}\n\n#display .circle {\n  stroke-opacity: 0.18;\n  stroke-width: 7px;\n  stroke: #000;\n}\n\n#print .circle {\n  stroke-opacity: 1;\n  stroke-width: 2px;\n  stroke: #000;\n  stroke-linecap: round;\n}\n\n#print .link {\n  stroke: #000;\n}\n\n#display .link {\n  stroke: rgba(160, 160, 160, 0.5);\n}\n\ntable {\n  border-collapse: collapse;\n  display: table;\n  width: 100%;\n  margin-bottom: 20px;\n}\n\ntd, th {\n  padding: 5px;\n  text-align: left;\n}\n\n#display th {\n  background: #212121\n}\n\ntd {\n  border-bottom: 1px solid #111;\n}\n\n.highlight {\n  filter: url(#drop-shadow-pulse);\n}\n\n.control-row {\n  padding: 5px 0px;\n}\n\n.btn {\n  display: inline-block;\n  padding: 0.35em 1.2em;\n  border: 0.1em solid #FFFFFF;\n  margin: 0 0.3em 0.3em 0;\n  border-radius: 0.12em;\n  box-sizing: border-box;\n  text-decoration: none;\n  background-color: transparent;\n  font-weight: 300;\n  color: #FFFFFF;\n  text-align: cent ...
